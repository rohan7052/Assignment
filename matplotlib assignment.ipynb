# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
ma = [39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25]
mi = [21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18]
mo=list(np.arange(1,13))

# %%
sns.regplot(x='months',y='max',data=df,ci=None,order=4)
sns.regplot(x='months',y='min',data=df,ci=None,order=4)
# Out:
# <AxesSubplot:xlabel='months', ylabel='min'>

# %%
df1=pd.read_csv('titanic.csv')
df1.head(2)
# Out:
#    pclass  survived                            name     sex    age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.00      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.92      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
vc=df1['sex'].value_counts()
vc
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
vc.plot(kind='pie',autopct = '%.2f',fontsize=20)
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
sns.scatterplot(x='age',y='fare',data=df1,hue='sex')
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>
